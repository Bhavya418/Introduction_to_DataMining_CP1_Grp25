# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # For plotting
import matplotlib.pyplot as plt

# %%
# !pip install autoviz
# !pip install xlrd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# from google.colab import drive
# drive.mount('/content/drive')

df = pd.read_csv("For_modeling.csv")
print(df.shape)
# Out:
# (9601139, 26)

# %%
df= df[df.index % 8 == 0]

# %% [markdown]
# Data Preprocessing

# %%
df.describe()
# Out:
#          Unnamed: 0      Duration      Distance         PLong         PLatd
# count  3.200380e+06  3.200380e+06  3.200380e+06  3.200380e+06  3.200380e+06  \
# mean   4.923152e+06  2.580183e+01  3.714422e+03  3.754760e+01  1.269908e+02
# std    2.841734e+06  2.505030e+01  3.959029e+03  4.439489e-02  8.258401e-02
# min    0.000000e+00  1.000000e+00  1.000000e+00  3.743727e+01  1.267986e+02
# 25%    2.466319e+06  8.000000e+00  1.230000e+03  3.751424e+01  1.269200e+02
# 50%    4.921318e+06  1.600000e+01  2.280000e+03  3.754685e+01  1.269943e+02
# 75%    7.389175e+06  3.600000e+01  4.630000e+03  3.757324e+01  1.270619e+02
# max    9.830309e+06  1.190000e+02  3.329000e+04  3.768972e+01  1.271803e+02
#
#               DLong         DLatd     Haversine        Pmonth          Pday
# count  3.200380e+06  3.200380e+06  3.200380e+06  3.200380e+06  3.200380e+06  \
# mean   3.754768e+01  1.269908e+02  1.869521e+00  7.578754e+00  1.576713e+01
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Duration      0
# Distance      0
# PLong         0
# PLatd         0
# DLong         0
# DLatd         0
# Haversine     0
# Pmonth        0
# Pday          0
# Phour         0
# Pmin          0
# PDweek        0
# Dmonth        0
# Dday          0
# Dhour         0
# Dmin          0
# DDweek        0
# Temp          0
# Precip        0
# Wind          0
# Humid         0
# Solar         0
# Snow          0
# GroundTemp    0
# Dust          0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Duration      0
# Distance      0
# PLong         0
# PLatd         0
# DLong         0
# DLatd         0
# Haversine     0
# Pmonth        0
# Pday          0
# Phour         0
# Pmin          0
# PDweek        0
# Dmonth        0
# Dday          0
# Dhour         0
# Dmin          0
# DDweek        0
# Temp          0
# Precip        0
# Wind          0
# Humid         0
# Solar         0
# Snow          0
# GroundTemp    0
# Dust          0
# dtype: int64

# %% [markdown]
# Removing the outliers

# %%
sns.boxplot(x=df['Duration'])
# Out:
# <AxesSubplot:xlabel='Duration'>

# %%
print(max(df.Duration))
print(min(df.Duration))
print(np.mean(df.Duration))
# Out:
# 119
# 1
# 25.801833219805147

# %%
#Removing the outliers from the trip duration
mean = np.mean(df['Duration'])
std = np.std(df['Duration'])
df = df[df['Duration']<= mean+3*std]
df = df[df['Duration']>= mean-3*std]

# %%
print(max(df.Duration))
print(min(df.Duration))
print(np.mean(df.Duration))
print(df.shape)
# Out:
# 100
# 1
# 23.752804920563932
# (3123707, 26)

# %%
sns.boxplot(x=df['Duration'])
# Out:
# <AxesSubplot:xlabel='Duration'>

# %%
sns.boxplot(x=df['Distance'])
# Out:
# <AxesSubplot:xlabel='Distance'>

# %%
print(max(df.Distance))
print(min(df.Distance))
print(np.mean(df.Distance))
# Out:
# 33290
# 1
# 3516.7956639339095

# %%
#Removing the outliers from the trip Distance
mean = np.mean(df['Distance'])
std = np.std(df['Distance'])
df = df[df['Distance']<= mean+3*std]
df = df[df['Distance']>= mean-3*std]

# %%
print(max(df.Distance))
print(min(df.Distance))
print(np.mean(df.Distance))
print(df.shape)
# Out:
# 14350
# 1
# 3187.2952792836654
# (3056337, 26)

# %%
sns.boxplot(x=df['Distance'])
# Out:
# <AxesSubplot:xlabel='Distance'>

# %%
sns.boxplot(x=df['PLong'])
# Out:
# <AxesSubplot:xlabel='PLong'>

# %%
print(max(df.PLong))
print(min(df.PLong))
print(np.mean(df.PLong))
# Out:
# 37.68972
# 37.437271
# 37.54790057372763

# %%
#Removing the outliers from the trip PLong
mean = np.mean(df['PLong'])
std = np.std(df['PLong'])
df = df[df['PLong']<= mean+3*std]
df = df[df['PLong']>= mean-3*std]

# %%
print(max(df.PLong))
print(min(df.PLong))
print(np.mean(df.PLong))
print(df.shape)
# Out:
# 37.680313
# 37.437271
# 37.5478015906518
# (3054187, 26)

# %%
sns.boxplot(x=df['PLong'])
# Out:
# <AxesSubplot:xlabel='PLong'>

# %%
sns.boxplot(x=df['Haversine'])
# Out:
# <AxesSubplot:xlabel='Haversine'>

# %%
print(max(df.Haversine))
print(min(df.Haversine))
print(np.mean(df.Haversine))
# Out:
# 22.63179886646668
# 0.0
# 1.7668623458757498

# %%
#Removing the outliers from the trip PLong
mean = np.mean(df['Haversine'])
std = np.std(df['Haversine'])
df = df[df['Haversine']<= mean+3*std]
df = df[df['Haversine']>= mean-3*std]

# %%
print(max(df.Haversine))
print(min(df.Haversine))
print(np.mean(df.Haversine))
print(df.shape)
# Out:
# 6.795183101732063
# 0.0
# 1.6249655672196475
# (2987363, 26)

# %%
sns.boxplot(x=df['Haversine'])
# Out:
# <AxesSubplot:xlabel='Haversine'>

# %%
sns.boxplot(x=df["DLong"])
# Out:
# <AxesSubplot:xlabel='DLong'>

# %%
print(max(df.DLong))
print(min(df.DLong))
print(np.mean(df.DLong))
# Out:
# 37.68972
# 37.437271
# 37.54793045307754

# %%
#Removing the outliers from the trip DLong
mean = np.mean(df['DLong'])
std = np.std(df['DLong'])
df = df[df['DLong']<= mean+3*std]
df = df[df['DLong']>= mean-3*std]

# %%
print(max(df.DLong))
print(min(df.DLong))
print(np.mean(df.DLong))
print(df.shape)
# Out:
# 37.680313
# 37.437271
# 37.54785478123859
# (2985755, 26)

# %%
sns.boxplot(x=df['DLong'])
# Out:
# <AxesSubplot:xlabel='DLong'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Duration', 'Distance', 'PLong', 'PLatd', 'DLong',
#        'DLatd', 'Haversine', 'Pmonth', 'Pday', 'Phour', 'Pmin', 'PDweek',
#        'Dmonth', 'Dday', 'Dhour', 'Dmin', 'DDweek', 'Temp', 'Precip', 'Wind',
#        'Humid', 'Solar', 'Snow', 'GroundTemp', 'Dust'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2985755 entries, 0 to 9601134
# Data columns (total 26 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   Duration    int64
#  2   Distance    int64
#  3   PLong       float64
#  4   PLatd       float64
#  5   DLong       float64
#  6   DLatd       float64
#  7   Haversine   float64
#  8   Pmonth      int64
#  9   Pday        int64
#  10  Phour       int64
#  11  Pmin        int64
#  12  PDweek      int64
#  13  Dmonth      int64
#  14  Dday        int64
#  15  Dhour       int64
#  16  Dmin        int64
#  17  DDweek      int64
#  18  Temp        float64
#  19  Precip      float64
#  20  Wind        float64
#  21  Humid       float64
#  22  Solar       float64
#  23  Snow        float64
#  24  GroundTemp  float64
#  25  Dust        float64
# dtypes: float64(13), int64(13)
# memory usage: 615.0 MB

# %% [markdown]
# Removing the unwanted columns or features

# %%
df = df.drop('Unnamed: 0', axis =1)

# %%
sns.heatmap(data=df.corr(),cmap='coolwarm', lw = 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# To understand the cluster analysis

# %%
import scipy
from scipy.cluster import hierarchy as hc
X = df

corr = np.round(scipy.stats.spearmanr(X).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(16,10))
dendrogram = hc.dendrogram(z, labels=X.columns, orientation='left', leaf_font_size=16)
plt.show()

# %%
#Removing the correlated features
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(df, 0.8)
df_drop = df.drop(corr_features,axis=1)

# %%
df_drop.columns
# Out:
# Index(['Duration', 'Distance', 'PLong', 'PLatd', 'Haversine', 'Pmonth', 'Pday',
#        'Phour', 'Pmin', 'PDweek', 'Dmin', 'Temp', 'Precip', 'Wind', 'Humid',
#        'Solar', 'Snow', 'Dust'],
#       dtype='object')

# %%
sns.heatmap(data=df_drop.corr(),cmap='coolwarm', lw = 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no more correlated features in the dataset

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
day = pd.value_counts(df['PDweek']).sort_index()
day.plot.bar(alpha = 0.5, color = 'red')
plt.title('PICKUPS OVER DAY OF WEEK', fontsize = 20)
plt.xlabel('WEEK OF DAY', fontsize = 18)
plt.ylabel('COUNT', fontsize = 18)
plt.xticks(ticks = [0,1,2,3,4,5, 6], labels = ['Sun', 'Mon', 'Tue', 'Wed', 'Thurs', 'Fri', 'Sat'])
plt.yticks(fontsize = 18)
# Out:
# (array([     0., 100000., 200000., 300000., 400000., 500000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
w = df["Wind"]

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['DLong'], y=df['PLong'], alpha=0.5)
plt.xlabel('Destination Longitude')
plt.ylabel('Pickup Longitude')
plt.title('Destination Longitude vs. Pickup Longitude')
plt.show()

# %% [markdown]
# Positive Linear Relationship: The linear pattern at a 45-degree angle suggests a positive linear relationship between Destination Longitude and Pickup Longitude. This means that as one of these variables increases, the other tends to increase as well. In your case, as Destination Longitude increases, Pickup Longitude tends to increase, and vice versa.
#
# Cross Line: The presence of a cross line between 37.45 and 37.70 indicates that there is a particular range of longitudes within which many of the observations fall for both destination and pickup. This range appears to be significant in your data.
#
# Clustered Data: The data points forming this linear pattern indicate that there might be a concentration of pickup and destination coordinates within this range. This could be due to specific geographic or operational reasons.
#
# Outliers: While a linear pattern is evident, I may want to check for any outliers or data points that deviate significantly from this pattern. Outliers could represent exceptional cases or data errors.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['DLatd'], y=df['PLatd'], alpha=0.5)
plt.xlabel('Destination Latitude')
plt.ylabel('Pickup Latitude')
plt.title('Destination Latitude vs. Pickup Latitude')
plt.show()

# %% [markdown]
# Distribution of Data: We can see how the data points are distributed across different destination and pickup latitudes. If there's a pattern or concentration of points in certain regions of the plot, it may indicate common pickup and destination latitude combinations.
#
# Correlation or Similarity: The scatterplot can reveal whether there's a correlation or similarity between the destination and pickup latitudes. If points tend to cluster or align in a particular direction, it suggests a relationship between the two variables.
#
# Outliers: Outliers, if present, might be visible as data points that are far away from the main cluster. These outliers can provide insights into unusual or unexpected patterns in the data.
#
# Density: The density of data points in different regions of the plot can indicate the most common combinations of destination and pickup latitudes. Dense areas suggest high frequency, while sparse areas suggest lower frequency.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['GroundTemp'], y=df['Temp'], alpha=0.5)
plt.xlabel('Ground Temperature')
plt.ylabel('Temperature')
plt.title('Ground Temperature vs. Temperature')
plt.show()

# %%
trip_dist = df['Distance']
trip_dur = df['Duration']
plt.scatter(trip_dist, trip_dur, s = 1)
plt.xlabel('Trip_Distance')
plt.ylabel('Trip_Duration')
plt.show()

# %%
sns.boxplot(x = df['Phour'], y = df['Duration'], width = 0.5).set_xlabel("Pickup_Hour", fontsize=1)
# Out:
# Text(0.5, 0, 'Pickup_Hour')

# %%
plt.hist(df['Duration'].values, bins=100)
plt.xlabel('Duration of trip')
plt.ylabel('Frequency')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1,ncols=1)
fig.set_size_inches(20, 20)
sns.pointplot(y = df.Duration,x=df.Distance,orient="v").set_xlabel("Distance")
# Out:
# Text(0.5, 0, 'Distance')

# %%
ax = sns.scatterplot(x=df["Dhour"], y=df["Haversine"], hue=df["Duration"], sizes=(20, 200))
# Out:
# C:\Users\YASH\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Dday'], y=df['Pday'], alpha=0.5)
plt.xlabel('Destination Day')
plt.ylabel('Pickup Day')
plt.title('Destination Day vs. Pickup Day')
plt.show()

# %% [markdown]
# (1.0, 1.0): This data point represents cases where both the "Destination Day" and "Pickup Day" are equal to 1.0. In other words, both the destination and pickup occurred on the same day (Day 1).
#
# (2.0, 1.0): This data point represents cases where the "Destination Day" is 2.0 (Day 2), and the "Pickup Day" is 1.0 (Day 1). This suggests that there are cases where the destination occurred on a different day (Day 2) compared to when the pickup occurred (Day 1).
#
# Based on these two observations, we can make the following conclusions:
#
# There appears to be limited variation in the data regarding the "Destination Day" and "Pickup Day" variables, with most cases falling into the categories mentioned above. The data suggests that a significant portion of the trips either begin and end on the same day (Day 1) or have the destination occurring one day after the pickup (Day 2 and Day 1).

# %%
# Categorical columns
categorical_columns = ['Pday', 'PDweek', 'Dday', 'DDweek']

# Create pie charts for each categorical column
for column in categorical_columns:
    counts = df[column].value_counts()
    labels = counts.index
    sizes = counts.values
    plt.figure(figsize=(8, 8))
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.title(f'Distribution of {column}')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %% [markdown]
# **1st Piechart - Distribution of Pday:**
# - Approximately 59.1% of the data corresponds to category 1.0 for "Pday."
# - About 40.9% of the data corresponds to category 2.0 for "Pday."
#
# **2nd Piechart - Distribution of Pdweek:**
# - Roughly 59.1% of the data is categorized as 0.0 for "Pdweek."
# - Approximately 40.9% of the data is categorized as 1.0 for "Pdweek."
#
# **3rd Piechart - Distribution of Dday:**
# - Around 58.5% of the data is associated with category 1.0 for "Dday."
# - About 41.5% of the data is associated with category 2.0 for "Dday."
#
# **4th Piechart - Distribution of Ddweek:**
# - Approximately 58.5% of the data is classified as 1.0 for "Ddweek."
# - About 41.5% of the data is classified as 2.0 for "Ddweek."
#
# Observations:
# 1. In the first two pie charts, "Pday" and "Pdweek," there is a distribution where one category represents approximately 59.1% of the data, and the other category represents about 40.9%. This suggests a somewhat balanced distribution between these two categories.
#
# 2. In the last two pie charts, "Dday" and "Ddweek," there is a similar pattern, with one category representing approximately 58.5% of the data and the other category representing about 41.5%. Again, this suggests a somewhat balanced distribution between these two categories.
#
# 3. The fact that these distributions are relatively balanced indicates that there is no overwhelming dominance of one category over the other in these columns.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Solar', y='GroundTemp', data=df, alpha=0.5)
plt.xlabel('Solar')
plt.ylabel('Ground Temperature')
plt.title('Solar vs Ground Temperature')
plt.show()

# %% [markdown]
# **Concentration Near 0.0 Solar**: The higher density of data points near the x-axis value of 0.0 for "Solar" suggests that many observations in  dataset have low solar values. This concentration around 0.0 may indicate that low solar conditions are more common idata.
#
# **Sparse Dots Away from 0.0**: As  move further away from 0.0 on the x-axis (e.g., to 0.2, 0.4, 0.6, etc., for "Solar"), you observe fewer data points. This indicates that higher solar values are less common in dataset, and such conditions are rarer.
#
# **Data Distribution**: The pattern suggests that the majority of data points have low solar values, and there are relatively few data points for higher solar values.

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x=df['Phour'], y=df['Duration'], hue=df['Distance'], size=df['Distance'], palette='viridis')
plt.xlabel('Hour of the Day')
plt.ylabel('Trip Duration')
plt.title('Duration vs Hour of the Day with Size of Distance')
plt.legend(title='Distance')
plt.show()
# Out:
# C:\Users\YASH\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 1. **Density Near Axis**: As we've observed, there is a higher density of data points near the x-axis (Hour of the Day). This suggests that a significant portion of the trips have shorter durations and are concentrated in the lower part of the plot, particularly during specific hours of the day.
#
# 2. **Sparse Dots as You Go Up**: As we move further away from the x-axis (higher values of Hour of the Day), the density of data points decreases. This indicates that trips with longer durations are less common, especially during certain hours.
#
# 3. **Color Coding**: The color of the dots corresponds to the "Distance," providing a visual cue for the distance of each trip. This can help us you distinguish between short-distance and long-distance trips within the scatterplot.
#
# In summary, this scatterplot visually captures the relationship between trip duration, hour of the day, and distance, showing that shorter trips are more frequent and are often concentrated at certain hours. Longer trips are less common but occur throughout the day.

# %%
#Distance vs Haversine
plt.rcParams['agg.path.chunksize'] = 10000
x = df.Haversine
y = df.Distance
plt.scatter(x, y)
plt.xlabel("Haversine")
plt.ylabel("Distance")
plt.show()

# %%
#Solar vs Ground Temp
x = df.GroundTemp
y = df.Solar
plt.scatter(x, y, s=1)
plt.xlabel("Ground Temp")
plt.ylabel("Solar")
plt.show()

# %%
from sklearn.model_selection import train_test_split, cross_validate, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
# assign features and the target class
X = df_drop.drop(columns=['Duration'])
y = df_drop['Duration']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=1)

# %%
X_train.head()
# Out:
#          Unnamed: 0  Distance      PLong       PLatd  Haversine  Pday  Phour
# 5859592     6009365      2830  37.517693  126.914299   1.836667    10      1  \
# 4854128     4976164      6910  37.486149  127.124802   5.203246    13     18
# 4654432     4772304      1010  37.520271  126.938881   0.777314     7     11
# 5730992     5875720      7290  37.556000  126.910454   2.579982     7     17
# 5433056     5569867      2510  37.649673  127.013451   1.725545    31     16
#
#          Pmin  PDweek  Dmin  Temp  Precip  Wind  Humid  Solar  Snow  Dust
# 5859592     6       0    24  20.5     0.0   1.7   58.0   0.00   0.0   9.0
# 4854128    21       0     2  33.1     0.0   3.1   59.0   0.72   0.0  26.0
# 4654432    26       1    33  31.4     0.0   0.8   59.0   1.30   0.0   5.0
# 5730992    12       4     9  24.5     0.0   3.2   37.0   1.04   0.0   0.0
# 5433056    15       4    40  29.7     0.0   3.0   51.0   2.27   0.0  13.0

# %%
y_train.head()
# Out:
# 8048994    85
# 5845002    65
# 5161248    11
# 3290193     4
# 5524845    47
# Name: Duration, dtype: int64

# %%
std_scaler = StandardScaler()
X_train_scaled = std_scaler.fit_transform(X_train)
X_test_scaled = std_scaler.fit_transform(X_test)
X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((937067, 17), (234267, 17))

# %%
print(X_train_scaled)
print(X_train_scaled.shape)
# Out:
# [[ 0.38043141 -0.19129851 -0.67710741 ... -0.79173405 -0.06168463
#   -0.97357398]
#  [ 0.01749297  0.93609806 -1.38656585 ... -0.00426053 -0.06168463
#   -0.26911855]
#  [-0.0541181  -0.6942058  -0.61912542 ...  0.63009314 -0.06168463
#   -1.1393282 ]
#  ...
#  [-0.33837077  0.49674499  0.80330007 ...  1.45037805 -0.06168463
#   -0.55918843]
#  [-0.27689576 -0.26314241 -0.25679421 ... -0.79173405 -0.06168463
#   -0.18624144]
#  [-1.35563472  0.27292361 -0.23594499 ...  2.60971406 -0.06168463
#    0.80828387]]
# (937067, 17)

# %%
X_test_scaled
# Out:
# array([[ 0.38494398, -0.75088157,  0.06804918, ...,  0.8052393 ,
#         -0.06079263, -0.80841153],
#        [ 1.6100292 , -0.73145547, -0.94150834, ..., -0.3873787 ,
#         -0.06079263,  1.02351818],
#        [ 1.04776373,  1.22780505,  1.51347256, ..., -0.79221233,
#         -0.06079263, -1.14148965],
#        ...,
#        [-0.56904547,  3.18429042, -1.07595218, ...,  0.46605436,
#         -0.06079263, -0.05898574],
#        [-0.08001874,  1.08904723, -0.61494714, ..., -0.79221233,
#         -0.06079263, -0.4753334 ],
#        [-1.37989458, -0.82858595,  0.51829961, ..., -0.79221233,
#         -0.06079263, -1.01658536]])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import median_absolute_error
from sklearn import metrics
import math
# Models-------------------------
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
lparams={'fit_intercept':[True], 'n_jobs':[None], 'normalize':[False]}
LM = GridSearchCV(estimator=LinearRegression(), cv=10,param_grid=lparams)
LM.fit(X_train,y_train())
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())
preds = LM.predict(X_train)
rmse(y_train,X_train)

# %%
def rmse(x,y):
    return math.sqrt(((x-y)**2).mean())

def print_score(m):
    res = [rmse(m.predict(X_train), y_train),rmse(m.predict(X_test), y_test),
           m.score(X_train, y_train),m.score(X_test, y_test),
           metrics.mean_absolute_error(m.predict(X_train), y_train),metrics.mean_absolute_error(m.predict(X_test), y_test),

          ]


    print(f" RMSE on training set: {res[0]} \n RMSE on test set: {res[1]} \n Score or Accuracy on training set: {res[2]} \n Score or Accuracy on test set: {res[3]} \n Mean absolute error on training set:{res[4]} \n Mean absolute error on test set :{res[5]} ")

# %% [markdown]
# Linear Regression

# %%
lModel = LinearRegression()
lModel.fit(X_train,y_train)
print_score(lModel)
# Out:
#  RMSE on training set: 14.142628583882853
#  RMSE on test set: 14.061777959779606
#  Score or Accuracy on training set: 0.5713737951363951
#  Score or Accuracy on test set: 0.5764095730570877
#  Mean absolute error on training set:8.949554832697192
#  Mean absolute error on test set :8.926407683561221

# %% [markdown]
# Random forest Regressor

# %%
rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)
print_score(rfr)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\YASH\OneDrive\Desktop\Data-Mining-Project1\Course_Project_1.ipynb Cell 87 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/YASH/OneDrive/Desktop/Data-Mining-Project1/Course_Project_1.ipynb#Y152sZmlsZQ%3D%3D?line=0'>1</a> rfr = RandomForestRegressor()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/YASH/OneDrive/Desktop/Data-Mining-Project1/Course_Project_1.ipynb#Y152sZmlsZQ%3D%3D?line=1'>2</a> rfr.fit(X_train, y_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/YASH/OneDrive/Desktop/Data-Mining-Project1/Course_Project_1.ipynb#Y152sZmlsZQ%3D%3D?line=2'>3</a> print_score(rfr)
#
# File c:\Users\YASH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
# ...

# %% [markdown]
# Polynomial Regression

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
# Models-------------------------
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import train_test_split, cross_validate, cross_val_score
from sklearn import preprocessing
import math

#Generating Test Data
train_df, test_df = train_test_split(df,test_size=0.20)
X_train = train_df[['Distance','Haversine','Dmin']]
# print(X_train.shape)
print(X_test.shape)
y_train = train_df["Duration"]

X_test = test_df[['Distance','Haversine','Dmin']]
# print(X_test.shape)
y_test = test_df["Duration"]
std_scaler = StandardScaler()
X_train_scaled = std_scaler.fit_transform(X_train)
X_test_scaled = std_scaler.fit_transform(X_test)
X_train_scaled.shape, X_test_scaled.shape

from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2, include_bias=False)
poly = PolynomialFeatures()
poly_X_train = poly.fit_transform(X_train)
poly_X_test = poly.transform(X_test)
regression = LinearRegression()

def score_metrics(actual,predicted):
  mae = mean_absolute_error(actual**2,predicted**2)
  print('mean absolute error is  :',mae)
  mse = mean_squared_error(actual**2,predicted**2)
  print('mean squared error is  :',mse)
  print('Root mean squared error is  :',np.sqrt(mse))
  print("R2 score is  :",r2_score(actual**2,predicted**2))

regression.fit(poly_X_train,y_train)
regression.score(poly_X_train,y_train)
poly_pred = regression.predict(poly_X_test)
score_metrics(y_test,poly_pred)
# Out:
# (234267, 17)
# mean absolute error is  : 546.2928931227449
# mean squared error is  : 1489537.198748989
# Root mean squared error is  : 1220.46597607184
# R2 score is  : 0.5233268403154401

# %%
X_train = train_df[['Distance','Haversine','Temp']]
# print(X_train.shape)
y_train = train_df["Duration"]

X_test = test_df[['Distance','Haversine','Temp']]
# print(X_test.shape)

y_test = test_df["Duration"]

std_scaler = StandardScaler()
X_train_scaled = std_scaler.fit_transform(X_train)
X_test_scaled = std_scaler.fit_transform(X_test)
X_train_scaled.shape, X_test_scaled.shape


poly = PolynomialFeatures(degree=2, include_bias=False)
poly = PolynomialFeatures()
poly_X_train = poly.fit_transform(X_train)
poly_X_test = poly.transform(X_test)
regression = LinearRegression()

def score_metrics(actual,predicted):
  mae = mean_absolute_error(actual**2,predicted**2)
  print('mean absolute error is  :',mae)
  mse = mean_squared_error(actual**2,predicted**2)
  print('mean squared error is  :',mse)
  print('Root mean squared error is  :',np.sqrt(mse))
  print("R2 score is  :",r2_score(actual**2,predicted**2))

regression.fit(poly_X_train,y_train)
regression.score(poly_X_train,y_train)
poly_pred = regression.predict(poly_X_test)
score_metrics(y_test,poly_pred)
# Out:
# mean absolute error is  : 544.7744265534101
# mean squared error is  : 1485061.467761722
# Root mean squared error is  : 1218.6309809625398
# R2 score is  : 0.5247591381012158

# %% [markdown]
# Gradient Boosting Linear Regression

# %%
GBR = GradientBoostingRegressor()
GBR.fit(X_train,y_train)
print_score(GBR)

# %%
xgbr = XGBRegressor()
xgbr.fit(X_train,y_train)
print_score(xgbr)

# %%
DTR = DecisionTreeRegressor()
DTR.fit(X_train,y_train)
print_score(DTR)

# %% [markdown]
# The random forest regressor and XGB regressor performs well on the data.

# %%
#Plot of feature importance
def rf_feat_importance(rfr, df):
    return pd.DataFrame({'cols':df.columns, 'imp':rfr.feature_importances_}
                       ).sort_values('imp', ascending=False)

# %%
def plot_fi(fi): return fi.plot('cols', 'imp', 'barh', figsize=(7,4), legend=False)

# %%
fi = rf_feat_importance(rfr, X_train)
plot_fi(fi[:30])
# Out:
# <AxesSubplot:ylabel='cols'>

# %% [markdown]
# Min-Max Standarization

# %%
from sklearn.preprocessing import MinMaxScaler
X_train = train_df[['Distance','Haversine','Temp','Wind','Humid','Snow','Dday']]
# print(X_train.shape)
print(X_test.shape)
y_train = train_df["Duration"]

X_test = test_df[['Distance','Haversine','Temp','Wind','Humid','Snow','Dday']]
# print(X_test.shape)
y_test = test_df["Duration"]

minmax_scale = MinMaxScaler()
size_scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled = minmax_scale.fit_transform(X_train)
X_test_scaled = minmax_scale.transform(X_test)
print(X_train_scaled)


from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2, include_bias=False)
poly = PolynomialFeatures()
poly_X_train = poly.fit_transform(X_train)
poly_X_test = poly.transform(X_test)
regression = LinearRegression()



def score_metrics(actual,predicted):
  mae = mean_absolute_error(actual**2,predicted**2)
  print('mean absolute error is  :',mae)
  mse = mean_squared_error(actual**2,predicted**2)
  print('mean squared error is  :',mse)
  print('Root mean squared error is  :',np.sqrt(mse))
  print("R2 score is  :",r2_score(actual**2,predicted**2))

regression.fit(poly_X_train,y_train)
regression.score(poly_X_train,y_train)
poly_pred = regression.predict(poly_X_test)
score_metrics(y_test,poly_pred)


#random forest Regressor

def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    errors = abs(predictions - test_labels)
    mape = 100 * np.mean(errors / test_labels)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))

    return accuracy

base_model = RandomForestRegressor(n_estimators = 20, random_state = 0)
base_model.fit(X_train_scaled,y_train)
base_accuracy = evaluate(base_model, X_test_scaled, y_test)
print(base_accuracy)
# Out:
# (234267, 6)
# [[0.01889513 0.02467607 0.56468531 ... 0.59090909 0.         0.9       ]
#  [0.02670552 0.02904127 0.74825175 ... 0.56818182 0.         0.5       ]
#  [0.19372766 0.04017698 0.49475524 ... 0.55681818 0.         0.26666667]
#  ...
#  [0.1672925  0.16905386 0.68356643 ... 0.60227273 0.         0.2       ]
#  [0.03061071 0.02599766 0.49300699 ... 0.60227273 0.         0.5       ]
#  [0.02009673 0.02641047 0.79895105 ... 0.56818182 0.         1.        ]]
# mean absolute error is  : 540.2675846183984
# mean squared error is  : 1467163.4064786956
# Root mean squared error is  : 1211.2652089772478
# R2 score is  : 0.5304867731217937
# Model Performance
# Average Error: 7.4031 degrees.
# Accuracy = 58.15%.
# 58.15201330348026

# %% [markdown]
# Changes on duration because of weather condition

# %%
from sklearn.preprocessing import MinMaxScaler
X_train = train_df[['Haversine','Temp','Wind','Humid','Snow','Dday','Pday']]
# print(X_train.shape)
print(X_test.shape)
y_train = train_df["Duration"]

X_test = test_df[['Haversine','Temp','Wind','Humid','Snow','Dday','Pday']]
# print(X_test.shape)
y_test = test_df["Duration"]

minmax_scale = MinMaxScaler()
size_scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled = minmax_scale.fit_transform(X_train)
X_test_scaled = minmax_scale.transform(X_test)
print(X_train_scaled)


from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=1, include_bias=False)
poly = PolynomialFeatures()
poly_X_train = poly.fit_transform(X_train)
poly_X_test = poly.transform(X_test)
regression = LinearRegression()



def score_metrics(actual,predicted):
  mae = mean_absolute_error(actual**2,predicted**2)
  print('mean absolute error is  :',mae)
  mse = mean_squared_error(actual**2,predicted**2)
  print('mean squared error is  :',mse)
  print('Root mean squared error is  :',np.sqrt(mse))
  print("R2 score is  :",r2_score(actual**2,predicted**2))

regression.fit(poly_X_train,y_train)
regression.score(poly_X_train,y_train)
poly_pred = regression.predict(poly_X_test)
score_metrics(y_test,poly_pred)

# %% [markdown]
# We tried various models including Linear Regression, Random Forest Regressor on various parameters
# - All parameters
# - Distance with Weather parameters
# - Only weather parameters
# - Distance without any weather parameters
#
# Conclusion :
# Random forest generator with all parameters after droping columns having high correlation gives best result this means that weather conditions have very little impact
